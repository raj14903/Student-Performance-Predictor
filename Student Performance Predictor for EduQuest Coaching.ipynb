# %%
# 📘 Student Performance Predictor for EduQuest Coaching
print('Hello from YBI Foundation 🚀')
# Out:
# Hello from YBI Foundation 🚀

# %% [markdown]
# Import necessary libraries

# %%
import pandas as pd

# %% [markdown]
# Read the dataset

# %%
df = pd.read_csv('/content/Student Performance Predictor for EduQuest Coaching.csv')

# %% [markdown]
# Data preprocessing

# %%
df.head(6)
# Out:
#    gender  age  parental_education  family_income  internet_access  \
# 0       0   14                   0       29591.84                1
# 1       0   16                   0       35222.46                1
# 2       0   14                   0       29730.93                1
# 3       1   15                   0       29074.09                1
# 4       0   19                   2       42305.33                1
# 5       1   18                   1       47544.20                1
#
#    previous_exam_score  attendance_rate  homework_completion_rate  \
# 0                93.25            91.01                     76.56
# 1                85.06            83.85                     64.82
# 2                79.93            86.71                     75.02
# 3                98.94            88.04                     55.50
# 4                64.54            61.22                     98.85
# 5                83.61            69.96                     62.04
#
# ...

# %%
df.shape
# Out:
# (1000, 14)

# %%
df.describe()
# Out:
#                age  family_income  previous_exam_score  attendance_rate  \
# count  1000.000000    1000.000000           1000.00000      1000.000000
# mean     16.496000   40053.207840             69.92909        80.429630
# std       1.697901    9800.512538             14.30842        11.550007
# min      14.000000   14302.140000             30.00000        60.050000
# 25%      15.000000   33566.487500             60.36750        70.547500
# 50%      17.000000   40566.090000             69.93500        80.985000
# 75%      18.000000   46650.012500             80.00750        90.380000
# max      19.000000   77007.250000            100.00000        99.990000
#
#        homework_completion_rate  class_participation_score  \
# count               1000.000000                1000.000000
# mean                  74.312590                   4.923780
# std                   14.572686                   2.909478
# min                   50.040000                   0.030000
# ...

# %%
# find the null data
df.isnull().sum()
# Out:
# gender                            0
# age                               0
# parental_education                0
# family_income                     0
# internet_access                   0
# previous_exam_score               0
# attendance_rate                   0
# homework_completion_rate          0
# class_participation_score         0
# number_of_absences                0
# extra_curricular_involvement    372
# learning_hours_per_week           0
# tutor_support                     0
# final_exam_score                  0
# dtype: int64

# %%
# drop the null data
df = df.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 628 entries, 0 to 999
# Data columns (total 14 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   gender                        628 non-null    object
#  1   age                           628 non-null    int64
#  2   parental_education            628 non-null    object
#  3   family_income                 628 non-null    float64
#  4   internet_access               628 non-null    object
#  5   previous_exam_score           628 non-null    float64
#  6   attendance_rate               628 non-null    float64
#  7   homework_completion_rate      628 non-null    float64
#  8   class_participation_score     628 non-null    float64
#  9   number_of_absences            628 non-null    int64
#  10  extra_curricular_involvement  628 non-null    object
#  11  learning_hours_per_week       628 non-null    float64
# ...

# %%
# convert categotical data into numerical data

# %%
# gender
df['gender'].value_counts()
# Out:
# gender
# Female    316
# Male      312
# Name: count, dtype: int64

# %%
df['gender'] = df['gender'].replace({'Female':1, 'Male':0})
# Out:
# /tmp/ipython-input-36-2527183941.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['gender'] = df['gender'].replace({'Female':1, 'Male':0})
# /tmp/ipython-input-36-2527183941.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['gender'] = df['gender'].replace({'Female':1, 'Male':0})

# %%
# parental_education
df['parental_education'].value_counts()
# Out:
# parental_education
# Diploma         198
# Graduate        182
# High School     181
# Postgraduate     67
# Name: count, dtype: int64

# %%
df['parental_education'] = df['parental_education'].replace({'Diploma':0,'High School':1,'Graduate':2,'Postgraduate':3})
# Out:
# /tmp/ipython-input-38-2274291104.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['parental_education'] = df['parental_education'].replace({'Diploma':0,'High School':1,'Graduate':2,'Postgraduate':3})
# /tmp/ipython-input-38-2274291104.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['parental_education'] = df['parental_education'].replace({'Diploma':0,'High School':1,'Graduate':2,'Postgraduate':3})

# %%
# internet_access
df['internet_access'].value_counts()
# Out:
# internet_access
# Yes    543
# No      85
# Name: count, dtype: int64

# %%
df['internet_access'] = df['internet_access'].replace({'Yes':1, 'No':0})
# Out:
# /tmp/ipython-input-40-505677688.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['internet_access'] = df['internet_access'].replace({'Yes':1, 'No':0})
# /tmp/ipython-input-40-505677688.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['internet_access'] = df['internet_access'].replace({'Yes':1, 'No':0})

# %%
# extra_curricular_involvement
df['extra_curricular_involvement'].value_counts()
# Out:
# extra_curricular_involvement
# Low         311
# Moderate    224
# High         93
# Name: count, dtype: int64

# %%
df['extra_curricular_involvement'] = df['extra_curricular_involvement'].replace({'Low':0,'Moderate':1,'High':2})
# Out:
# /tmp/ipython-input-42-422224587.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['extra_curricular_involvement'] = df['extra_curricular_involvement'].replace({'Low':0,'Moderate':1,'High':2})
# /tmp/ipython-input-42-422224587.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['extra_curricular_involvement'] = df['extra_curricular_involvement'].replace({'Low':0,'Moderate':1,'High':2})

# %%
# tutor_support
df['tutor_support'].value_counts()
# Out:
# tutor_support
# Yes    348
# No     280
# Name: count, dtype: int64

# %%
df['tutor_support'] = df['tutor_support'].replace({'Yes':1, 'No':0})
# Out:
# /tmp/ipython-input-44-1189672181.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['tutor_support'] = df['tutor_support'].replace({'Yes':1, 'No':0})
# /tmp/ipython-input-44-1189672181.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tutor_support'] = df['tutor_support'].replace({'Yes':1, 'No':0})

# %% [markdown]
# Specify X and y

# %%
X = df[['gender','age','parental_education','family_income','internet_access','previous_exam_score','attendance_rate',
        'homework_completion_rate','class_participation_score','number_of_absences', 'extra_curricular_involvement',
        'learning_hours_per_week','tutor_support']]
y = df['final_exam_score']

# %% [markdown]
# Dataset splitting

# %%
# use the scikit-learn library
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X, y ,train_size=0.75, random_state=2529)

# %% [markdown]
# Model selection

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %% [markdown]
# Train the model

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# Prediction

# %%
y_pred = model.predict(X_test)

# %% [markdown]
# Evaluation

# %%
# using mean_absolute_percentage_error
from sklearn.metrics import mean_absolute_percentage_error
mean_absolute_percentage_error(y_test,y_pred)
# Out:
# 0.057436091073860426

# %% [markdown]
# The MAPE value of 5.75% indicates the model is predecting the test data accurately with only a small error
